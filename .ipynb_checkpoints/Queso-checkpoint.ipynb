# %% [markdown]
# # *Modelo de Optimización para la Demanda de Queso Costeño*

# %% [markdown]
# El modelo de optimización presentado está diseñado para gestionar la demanda de queso costeño a través de una plataforma de marketplace, utilizando múltiples centros de acopio. Su objetivo principal es minimizar los costos asociados con el cumplimiento de la demanda del cliente, considerando los costos de transporte, tiempos de alistamiento y producción potencial en cada centro. El modelo busca reducir los costos totales de distribución en un sistema complejo que involucra un centro principal y varios centros secundarios, asegurando que se satisfaga la demanda total con la menor inversión en costos posible, mientras se cumplen las restricciones de capacidad y tiempo.
#
# **Variables del Problema**
#
# **N**: Número de centros de acopio.
#
# **CAi**: Identificador del centro de acopio i para i=0…N donde i≠p. Estos centros de acopio complementan las unidades de producto de la demanda que el centro de acopio principal no tiene disponibles. Los centros de acopio **CAi** despachan hacia el centro de acopio principal.
#
# **CAp**: Identificador del centro de acopio principal p (**p**∈[0,N] y **p**≠i). Este centro de acopio atiende directamente al cliente y es responsable de enviar la demanda completa al cliente.
#
# **K(CAi)**: Cantidad del producto que se despacha desde el centro de acopio **CAi**, incluyendo unidades en stock y unidades potenciales que pueden estar listas en poco tiempo.
#
# **Precio(CAi)**: Precio por kilo del producto despachado desde el centro de acopio **CAi**.
#
# **cTransp(CAi)**: Costo del transporte del pedido desde el centro de acopio **CAi** a su destino.
#
# **TiempoAlistam(CAi)**: Tiempo en horas para alistar el pedido desde el centro de acopio **CAi** a su destino.
#
# **TiempoMaxDefinido**: Tiempo máximo definido para considerar la producción potencial.
#
# **TiempoTransp(CAi)**: Tiempo de transporte desde el centro de acopio **CAi** a su destino.
#
# **Tiempo(CAi)**: Tiempo total en horas para que el pedido llegue desde el centro de acopio **CAi** a su destino, sumando el tiempo de alistamiento y el tiempo de transporte.
#
# **cTiempo**: Costo adicional por cada unidad de tiempo contemplado en la variable **Tiempo(CAi)**.
#
# **Demanda**: Cantidad de producto solicitada por el cliente.
#
# **Stock(CAi)**: Stock del producto en el centro de acopio **CAi**.
#
# **Ppotencial(CAi)**: Cantidad de producto que potencialmente puede estar disponible en poco tiempo (potencial del día).

# %% [markdown]
# *Código desarrollado para la resolución del problema*

# %% [markdown]
# # IMPORTACIONES

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tabulate import tabulate
from prettytable import PrettyTable
from termcolor import colored
import openpyxl
import time
import pandas as pd
import pyomo.environ as pyo
from sqlalchemy import create_engine
import pandas as pd
import pymysql

# %% [markdown]
# **demanda**: Cantidad de producto de acuerdo con la categoría del pedido a satisfacer.
#
# **costo_transporte**: Costo por unidad de tiempo de espera para satisfacer la demanda.
#
# **id**: Identificadores de Centro de Acopio (CAi).
#
# **kg**: Stock del Producto en el Centro de Acopio (Stock(CAi)).
#
# **produccion_potencial**: (Ppotencial(CAi)).
#
# **costos_transporte**: (cTransp(CAi)).
#
# **precio**: Precio del Producto por Kilo (Precio(CAi)).
#
# **tiempos_transporte**:Tiempos de Transporte (TiempoTransp(CAi)).
#
# **tiempo_alistamiento**:Tiempos de Alistamiento (TiempoAlistam(CAi)).

# %% [markdown]
# # Creación de tablas de acuerdo al centro de acopio principal asignado

# %%
# Configurar conexión a la base de datos
engine = create_engine('mysql+pymysql://root:%40DaztanDesarrollador11%40@localhost:3306/marketplace')

# Consulta SQL: Datos de centros de acopio y productos
query_centros_acopio = """
SELECT 
    collection_center_id AS Id_CA, 
    MAX(quantity) AS Stock,
    MAX(production_capacity) AS Ppotencial,
    MAX(price) AS Precio, 
    MAX(transport_cost) AS Ctransp, 
    MAX(transport_time) AS TiempoTransp, 
    MAX(packing_time) AS TiempoAlistam,
    inventories.product_id AS Product,
    client_transports.city_id
FROM inventories
INNER JOIN client_transports 
    ON client_transports.sender_center_id = inventories.collection_center_id
INNER JOIN collection_centers 
    ON collection_centers.id = inventories.collection_center_id
INNER JOIN products 
    ON products.id = inventories.product_id
INNER JOIN producer_products 
    ON producer_products.product_id = inventories.product_id
WHERE client_transports.city_id = 498
GROUP BY collection_center_id, inventories.product_id
ORDER BY collection_center_id ASC;
"""

# Consulta SQL: Datos de transporte
query_transporte = """
SELECT 
    sender_center_id, 
    receiver_center_id, 
    transport_time, 
    transport_cost 
FROM transports;
"""

# Cargar datos en DataFrames
centros_acopio_df = pd.read_sql(query_centros_acopio, engine)
transporte_df = pd.read_sql(query_transporte, engine)

# Validar columnas requeridas
required_columns_centros = ['Id_CA', 'Stock', 'Ppotencial', 'Precio', 'Ctransp', 'TiempoTransp', 'TiempoAlistam']
required_columns_transporte = ['sender_center_id', 'receiver_center_id', 'transport_time', 'transport_cost']

assert all(col in centros_acopio_df.columns for col in required_columns_centros), "Faltan columnas en centros_acopio_df"
assert all(col in transporte_df.columns for col in required_columns_transporte), "Faltan columnas en transporte_df"

# Rellenar valores faltantes con 0
centros_acopio_df.fillna(0, inplace=True)
transporte_df.fillna(0, inplace=True)

# Crear matrices de costos y tiempos desde transporte_df
costos_transporte_df = transporte_df.pivot(
    index='sender_center_id', 
    columns='receiver_center_id', 
    values='transport_cost'
).fillna(0)

tiempos_transporte_df = transporte_df.pivot(
    index='sender_center_id', 
    columns='receiver_center_id', 
    values='transport_time'
).fillna(0)

# Eliminar las palabras "sender" y "receiver" de las etiquetas
costos_transporte_df.index.name = None
costos_transporte_df.columns.name = None
tiempos_transporte_df.index.name = None
tiempos_transporte_df.columns.name = None

# Formatear tablas en el estilo solicitado
centros_acopio_tabla = tabulate(centros_acopio_df, headers="keys", tablefmt="grid", showindex=False)
costos_transporte_tabla = tabulate(costos_transporte_df, headers="keys", tablefmt="grid", showindex=True)
tiempos_transporte_tabla = tabulate(tiempos_transporte_df, headers="keys", tablefmt="grid", showindex=True)

# Imprimir tablas en formato tabular
print("Centros de Acopio:")
print(centros_acopio_tabla)

print("\nMatriz de Costos de Transporte:")
print(costos_transporte_tabla)

print("\nMatriz de Tiempos de Transporte:")
print(tiempos_transporte_tabla)

# Retornar los DataFrames como resultado final
# centros_acopio_df, tiempos_transporte_df, costos_transporte_df
# Out:
# Centros de Acopio:
# +---------+---------+--------------+----------+-----------+----------------+-----------------+-----------+-----------+
# |   Id_CA |   Stock |   Ppotencial |   Precio |   Ctransp |   TiempoTransp |   TiempoAlistam |   Product |   city_id |
# +=========+=========+==============+==========+===========+================+=================+===========+===========+
# |       1 |    1256 |          223 |    20571 |   6664.86 |          10.12 |         8.59621 |         1 |       498 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+-----------+-----------+
# |

# +----+---------+---------+---------+---------+----------+----------+----------+---------+----------+
# |  7 | 5.73333 | 3.83333 | 5.78333 | 9.41667 | 10.1167  | 11.4167  |  0       | 1.555   |  0.9     |
# +----+---------+---------+---------+---------+----------+----------+----------+---------+----------+
# |  8 | 3.45    | 2.3     | 4.25    | 7.88333 |  8.58333 |  9.88333 |  1.555   | 0       |  1.515   |
# +----+---------+---------+---------+---------+----------+----------+----------+---------+----------+
# |  9 | 4.95    | 3.8     | 5.75    | 9.38333 | 10.0833  | 11.4167  |  0.9     | 1.515   |  0       |
# +----+---------+---------+---------+---------+----------+----------+----------+---------+----------+

# %%
# Funciones reutilizadas del modelo anterior
def obtener_costos_y_tiempos(id_centro_acopio, centro_principal, costos_transporte_df, tiempos_transporte_df):
    if id_centro_acopio == centro_principal:
        return 0, 0
    costo_transporte = costos_transporte_df.at[centro_principal, id_centro_acopio]
    tiempo_transporte = tiempos_transporte_df.at[centro_principal, id_centro_acopio]
    return costo_transporte, tiempo_transporte

def agregar_fila_final(lista_filas, id_centro_acopio, cantidadS, cantidadP, precio, costo_transporte, tiempo_transporte, tiempo_alistamiento):
    lista_filas.append({
        'Id_CA': id_centro_acopio,
        'CantidadS': cantidadS,
        'CantidadP': cantidadP,
        'Precio': precio,
        'Ctransp': costo_transporte,
        'TiempoTransp': tiempo_transporte,
        'TiempoAlistam': tiempo_alistamiento
    })

def generar_dataframe_centros(centro_principal):
    filas_finales = []
    for _, row in centros_acopio_df.iterrows():
        id_centro_acopio = row['Id_CA']
        precio = row['Precio']
        cantidad_stock = row['Stock']
        cantidad_potencial = row['Ppotencial']
        tiempo_alistamiento = row['TiempoAlistam']
        costo_transporte, tiempo_transporte = obtener_costos_y_tiempos(
            id_centro_acopio, centro_principal, costos_transporte_df, tiempos_transporte_df
        )
        agregar_fila_final(filas_finales, id_centro_acopio, cantidad_stock, cantidad_potencial,
                           precio, costo_transporte, tiempo_transporte, tiempo_alistamiento)
    return pd.DataFrame(filas_finales)


def costoTransp_tiempo_CAi2CAP(centro_principal):
    index_centro_principal = centros_acopio_df.loc[centros_acopio_df['Id_CA'] == centro_principal].index[0]
    costos_df = costos_transporte_df.iloc[[index_centro_principal]].reset_index(drop=True)
    tiempos_df = tiempos_transporte_df.iloc[[index_centro_principal]].reset_index(drop=True)
    return costos_df, tiempos_df
def costoTransp_tiempo_CAi2CAP(centro_principal):
    index_centro_principal = centros_acopio_df.loc[centros_acopio_df['Id_CA'] == centro_principal].index[0]
    costos_df = costos_transporte_df.iloc[[index_centro_principal]].reset_index(drop=True)
    tiempos_df = tiempos_transporte_df.iloc[[index_centro_principal]].reset_index(drop=True)
    return costos_df, tiempos_df
    def idx_primera_asignacion(CAP, centros_df_CAP, demanda):
     idx_CAP = centros_df_CAP.loc[centros_df_CAP['Id_CA'] == CAP].index[0]
     cant_asignada = min(centros_df_CAP.loc[idx_CAP, 'CantidadS'], demanda)
     return idx_CAP, cant_asignada
def objective_rule(model):
        total_cost = sum(
             model.S[i] * model.Precio[i] + (model.CTransp[i] + model.TiempoTransp[i] * model.costo_tiempo)*model.bs[i] + 
             model.P[i] * model.Precio[i] + (model.TiempoAlistam[i] * model.costo_tiempo)*model.bp[i]
            for i in model.I )
        return total_cost
    
def create_model(demanda_cliente, centros_df, idx_CAP, costo_tiempo):
    num_centros = len(centros_df)
    bigM = centros_df['CantidadS'].sum() + centros_df['CantidadP'].sum() + 1000
    
    model = pyo.ConcreteModel()
    model.I = pyo.RangeSet(0, num_centros - 1)
    model.demanda = pyo.Param(initialize=demanda_cliente)
    model.costo_tiempo = pyo.Param(initialize=costo_tiempo, mutable=True, within=pyo.NonNegativeReals)
    model.bigM = pyo.Param(initialize=bigM, within=pyo.NonNegativeReals)
       
    model.CantidadS = pyo.Param(model.I, initialize=centros_df['CantidadS'].to_dict())
    model.CantidadP = pyo.Param(model.I, initialize=centros_df['CantidadP'].to_dict())
    model.Precio = pyo.Param(model.I, initialize=centros_df['Precio'].to_dict())
    model.CTransp = pyo.Param(model.I, initialize=centros_df['Ctransp'].to_dict())
    model.TiempoTransp = pyo.Param(model.I, initialize=centros_df['TiempoTransp'].to_dict())
    model.TiempoAlistam = pyo.Param(model.I, initialize=centros_df['TiempoAlistam'].to_dict())
    model.CentroPrincipal = pyo.Param(initialize=idx_CAP)
    
    model.S = pyo.Var(model.I, within=pyo.NonNegativeReals)
    model.P = pyo.Var(model.I, within=pyo.NonNegativeReals)
    model.bp = pyo.Var(model.I, within=pyo.Binary)
    model.bs = pyo.Var(model.I, within=pyo.Binary)
    
    model.DemandaSatisfecha = pyo.Constraint(expr=sum(model.S[i] + model.P[i] for i in model.I) >= model.demanda)
    model.LimiteCantidadS = pyo.Constraint(model.I, rule=lambda model, i: model.S[i] <= model.CantidadS[i])
    model.LimiteCantidadP = pyo.Constraint(model.I, rule=lambda model, i: model.P[i] <= model.CantidadP[i])
   
    def first_asignation(model):
        return model.S[model.CentroPrincipal] >= model.CantidadS[model.CentroPrincipal]
    model.CAP = pyo.Constraint(expr=first_asignation)

    def pot_IF_stock_ok(model, i):
        return model.S[i] * bigM >= model.P[i]
    model.pot_IF_stock = pyo.Constraint(model.I, rule=pot_IF_stock_ok)
    
    def TiempoAlistam_IF_pot_ok(model, i):
        return bigM * model.bp[i] >= model.P[i]
    model.TiempoAlistam_IF_pot = pyo.Constraint(model.I, rule=TiempoAlistam_IF_pot_ok)

    def TiempoCostoTransp_IF_stock_ok(model, i):
        return bigM * model.bs[i] >= model.S[i]
    model.TiempoCostoTransp_IF_stock = pyo.Constraint(model.I, rule=TiempoCostoTransp_IF_stock_ok)
    
    model.CostoTotal = pyo.Objective(rule=objective_rule, sense=pyo.minimize)
    
    return model

    
def print_asignation(model, Ids, centros_df_CAP, verbose=0):
    cant_total = 0
    CA_Ids = centros_df_CAP['Id_CA']
    
    asignaciones = {
        'CentroAcopio': [],
        'Stock': [],
        'Potencial': [],
        'BS': [],
        'BP': [],
        'CostoStock': [],
        'CostoPotencial': []
    }
    
    for i in model.I:
        cantStock = pyo.value(model.S[i])
        cantPot = pyo.value(model.P[i])
        
        cant_total += cantStock + cantPot
        
        asignaciones['CentroAcopio'].append(CA_Ids[i])
        asignaciones['Stock'].append(cantStock)
        asignaciones['Potencial'].append(cantPot)
        
        bs_value = pyo.value(model.bs[i])
        bp_value = pyo.value(model.bp[i])
        
        costo_stock = cantStock * centros_df_CAP['Precio'][i] + (centros_df_CAP['Ctransp'][i] + centros_df_CAP['TiempoTransp'][i] * 100) * bs_value
        costo_potencial = cantPot * centros_df_CAP['Precio'][i] + (centros_df_CAP['TiempoAlistam'][i] * 100) * bp_value
        
        asignaciones['BS'].append(bs_value)
        asignaciones['BP'].append(bp_value)
        asignaciones['CostoStock'].append(costo_stock)
        asignaciones['CostoPotencial'].append(costo_potencial)
        
        print(f"Centro: {CA_Ids[i]} | Stock: {cantStock:,.2f} | Potencial: {cantPot:,.2f} | SAV: {bs_value:,.2f} | PAV: {bp_value:,.2f} | CostoStock: {costo_stock:,.2f} | CostoPotencial: {costo_potencial:,.2f}")
    
    print(f'\nDemanda: {cant_total:,.2f} kg')
    print(f'Costo minimizado total: ${pyo.value(model.CostoTotal):,.2f}')
    
    if verbose:
        centros_df_CAP['cantStock_asignada'] = asignaciones['Stock']
        centros_df_CAP['cantPot_asignada'] = asignaciones['Potencial']
        centros_df_CAP['costo_stock'] = asignaciones['CostoStock']
        centros_df_CAP['costo_Potencial'] = asignaciones['CostoPotencial']
    
    return asignaciones
    
def costo_CAP(idx_CAP, centros_df_CAP, cant_tomada, costo_tiempo):
    precio = centros_df_CAP.loc[idx_CAP, 'Precio']
    costo_transp = centros_df_CAP.loc[idx_CAP, 'Ctransp'] 
    costo_tiempo_transp  = centros_df_CAP.loc[idx_CAP, 'TiempoTransp'] * costo_tiempo
    costo_CAP = cant_tomada*precio + costo_transp + costo_tiempo_transp   
    return costo_CAP
demanda_cliente = 15000
CA_Ids = centros_acopio_df['Id_CA']
CAP_sols = []
costo_tiempo = 100

# DataFrame para almacenar resultados de cada centro de acopio como centro principal
resultados_df = pd.DataFrame(columns=['CentroPrincipal', 'CostoTotal'])

# Bucle de optimización para cada centro de acopio como principal
for Ids in CA_Ids:
    print('-' * 50)
    print(f'\n Optimizando para {Ids} como centro principal...')
    
    centros_df_CAP = generar_dataframe_centros(Ids)
    costos_df, tiempos_df = costoTransp_tiempo_CAi2CAP(Ids)
    
    idx_CAP, cant_inicial_asignada = idx_primera_asignacion(Ids, centros_df_CAP, demanda_cliente)
    
    # Si el stock inicial cubre la demanda, calculamos el costo directamente
    if demanda_cliente <= cant_inicial_asignada:
        costo = costo_CAP(idx_CAP, centros_df_CAP, cant_inicial_asignada, costo_tiempo)
        CAP_sols.append((Ids, costo))
        resultados_df.loc[len(resultados_df)] = [Ids, costo]
        print(f'Solución para el CAP: {Ids}')
        print(f'-> Stock: {cant_inicial_asignada}, costo: {costo}')
        continue
        
    # Crear el modelo para los centros de acopio que no cumplen la demanda con el stock inicial
    model = create_model(demanda_cliente, centros_df_CAP, idx_CAP, costo_tiempo)
    solver = pyo.SolverFactory('glpk')
    results = solver.solve(model, tee=False)
    
    # Verificar si la solución fue óptima
    if results.solver.termination_condition != pyo.TerminationCondition.optimal:
        print(f"Centro de acopio: {Ids}")
        print(f"El modelo no se resolvió de manera óptima. Estado: {results.solver.termination_condition}")
        print("Posibles razones: restricciones demasiado estrictas, falta de stock o demanda demasiado alta.")
    else:
        costo_total = pyo.value(model.CostoTotal)
        CAP_sols.append((Ids, costo_total))
        resultados_df.loc[len(resultados_df)] = [Ids, costo_total]
        print_asignation(model, Ids, centros_df_CAP)
        print('-' * 50)

# Encontrar la mejor solución
mejor_sol = min(CAP_sols, key=lambda t: t[1])
print(f'\n\nLa mejor solución encontrada fue: ${mejor_sol[1]:,.2f}, CAP: {mejor_sol[0]}')

# Formatear la columna 'CostoTotal' para mostrar valores en formato monetario con el símbolo de peso
resultados_df['CostoTotal'] = resultados_df['CostoTotal'].apply(lambda x: f"${x:,.2f}")

# Mostrar el DataFrame con los costos
print("\nTabla de análisis costos:\n")
print(resultados_df)

# Convertir la columna 'CostoTotal' a tipo float para la gráfica
resultados_df['CostoTotal_float'] = resultados_df['CostoTotal'].replace('[\$,]', '', regex=True).astype(float)
print(f"\nCentro de acopio Principal: {mejor_sol[0]} \nCosto de la demanda: ${mejor_sol[1]:,.2f}")
# Out:
# --------------------------------------------------
#
#  Optimizando para 1 como centro principal...
# Centro: 1.0 | Stock: 1,256.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 25,837,176.00 | CostoPotencial: 0.00
# Centro: 2.0 | Stock: 1,830.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 37,647,294.31 | CostoPotencial: 0.00
# Centro: 3.0 | Stock: 1,350.00 | Potencial: 73.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,774,036.13 | CostoPotencial: 1,502,458.67
# Centro: 4.0 | Stock: 1,353.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,835,888.20 | CostoPotencial: 4,588,125.15
# Centro: 5.0 | Stock: 2,068.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 42,545,897.99 | CostoPotencial: 0.00
# Centro: 6.0 | Stock: 2,236.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 46,001,661.63 | CostoPotencial: 0.00
# Centro: 7.0 | Stock: 1,307.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 26,890,646.32 | CostoPotencial: 0.00
# Centro: 8.0 | Stock: 1,926.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 39,622,363.18 | CostoPotencial: 0.00
# Centro: 9.0 | Stock: 1,155.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 23,763,260.08 | CostoPotencial: 4,588,103.69
#
# Demanda: 15,000.00 kg
# Costo minimizado total: $308,596,911.35
# --------------------------------------------------
# --------------------------------------------------
#
#  Optimizando para 2 como centro principal...
# Centro: 1.0 | Stock: 1,256.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 25,839,540.31 | CostoPotencial: 0.00
# Centro: 2.0 | Stock: 1,830.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 37,644,930.00 | CostoPotencial: 0.00
# Centro: 3.0 | Stock: 1,350.00 | Potencial: 73.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,773,214.31 | CostoPotencial: 1,502,458.67
# Centro: 4.0 | Stock: 1,353.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 27,836,646.80 | CostoPotencial: 0.00
# Centro: 5.0 | Stock: 2,068.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 42,546,669.24 | CostoPotencial: 0.00
# Centro: 6.0 | Stock: 2,236.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 46,003,583.42 | CostoPotencial: 4,588,154.62
# Centro: 7.0 | Stock: 1,307.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 26,889,204.97 | CostoPotencial: 0.00
# Centro: 8.0 | Stock: 1,926.00 | Potencial: 0.00 | SAV: 1.00 | PAV: 0.00 | CostoStock: 39,621,490.78 | CostoPotencial: 0.00
# Centro: 9.0 | Stock: 1,155.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 23,762,387.69 | CostoPotencial: 4,588,103.69
#
# Demanda: 15,000.00 kg
# Costo minimizado total: $308,596,384.49
# --------------------------------------------------
# --------------------------------------------------
#
#  Optimizando para 3 como centro principal...
# Centro: 1.0 | Stock: 1,256.00 | Potencial: 113.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 25,840,362.13 | CostoPotencial: 2,325,382.62
# Centro: 2.0 | Stock: 1,830.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 37,647,294.31 | CostoPotencial: 4,588,135.55
# Centro: 3.0 | Stock: 1,350.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,770,850.00 | CostoPotencial: 4,588,108.67
# Centro: 4.0 | Stock: 1,353.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,836,684.74 | CostoPotencial: 4,588,125.15
# Centro: 5.0 | Stock: 2,068.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 42,544,772.73 | CostoPotencial: 4,588,175.70
# Centro: 6.0 | Stock: 2,236.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 46,001,686.91 | CostoPotencial: 4,588,154.62
# Centro: 7.0 | Stock: 1,307.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 26,890,684.25 | CostoPotencial: 4,588,144.39
# Centro: 8.0 | Stock: 1,926.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 39,622,970.06 | CostoPotencial: 4,588,134.67
# Centro: 9.0 | Stock: 0.00 | Potencial: 0.00 | SAV: 0.00 | PAV: 0.00 | CostoStock: 0.00 | CostoPotencial: 0.00
#
# Demanda: 15,000.00 kg
# Costo minimizado total: $308,597,666.50
# --------------------------------------------------
# --------------------------------------------------
#
#  Optimizando para 4 como centro principal...
# Centro: 1.0 | Stock: 1,256.00 | Potencial: 113.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 25,840,501.20 | CostoPotencial: 2,325,382.62
# Centro: 2.0 | Stock: 1,830.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 37,649,013.80 | CostoPotencial: 4,588,135.55
# Centro: 3.0 | Stock: 1,350.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,774,971.74 | CostoPotencial: 4,588,108.67
# Centro: 4.0 | Stock: 1,353.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,832,563.00 | CostoPotencial: 4,588,125.15
# Centro: 5.0 | Stock: 2,068.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 42,542,572.78 | CostoPotencial: 4,588,175.70
# Centro: 6.0 | Stock: 2,236.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 45,998,336.42 | CostoPotencial: 4,588,154.62
# Centro: 7.0 | Stock: 1,307.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 26,893,440.51 | CostoPotencial: 4,588,144.39
# Centro: 8.0 | Stock: 1,926.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 39,625,726.31 | CostoPotencial: 4,588,134.67
# Centro: 9.0 | Stock: 0.00 | Potencial: 0.00 | SAV: 0.00 | PAV: 0.00 | CostoStock: 0.00 | CostoPotencial: 0.00
#
# Demanda: 15,000.00 kg
# Costo minimizado total: $308,599,487.14
# --------------------------------------------------
# --------------------------------------------------
#
#  Optimizando para 5 como centro principal...
# Centro: 1.0 | Stock: 1,256.00 | Potencial: 113.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 25,842,245.99 | CostoPotencial: 2,325,382.62
# Centro: 2.0 | Stock: 1,830.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 37,650,771.24 | CostoPotencial: 4,588,135.55
# Centro: 3.0 | Stock: 1,350.00 | Potencial: 223.00 | SAV: 1.00 | PAV: 1.00 | CostoStock: 27,774,794.73 | CostoPotencial: 4,588,108.67
# Centro: 4.0 | Stock: