# %% [markdown]
# # *Modelo de Optimización para la Demanda de Queso Costeño*

# %% [markdown]
# El modelo de optimización presentado está diseñado para gestionar la demanda de queso costeño a través de una plataforma de marketplace, utilizando múltiples centros de acopio. Su objetivo principal es minimizar los costos asociados con el cumplimiento de la demanda del cliente, considerando los costos de transporte, tiempos de alistamiento y producción potencial en cada centro. El modelo busca reducir los costos totales de distribución en un sistema complejo que involucra un centro principal y varios centros secundarios, asegurando que se satisfaga la demanda total con la menor inversión en costos posible, mientras se cumplen las restricciones de capacidad y tiempo.
#
# **Variables del Problema**
#
# **N**: Número de centros de acopio.
#
# **CAi**: Identificador del centro de acopio i para i=0…N donde i≠p. Estos centros de acopio complementan las unidades de producto de la demanda que el centro de acopio principal no tiene disponibles. Los centros de acopio **CAi** despachan hacia el centro de acopio principal.
#
# **CAp**: Identificador del centro de acopio principal p (**p**∈[0,N] y **p**≠i). Este centro de acopio atiende directamente al cliente y es responsable de enviar la demanda completa al cliente.
#
# **K(CAi)**: Cantidad del producto que se despacha desde el centro de acopio **CAi**, incluyendo unidades en stock y unidades potenciales que pueden estar listas en poco tiempo.
#
# **Precio(CAi)**: Precio por kilo del producto despachado desde el centro de acopio **CAi**.
#
# **cTransp(CAi)**: Costo del transporte del pedido desde el centro de acopio **CAi** a su destino.
#
# **TiempoAlistam(CAi)**: Tiempo en horas para alistar el pedido desde el centro de acopio **CAi** a su destino.
#
# **TiempoMaxDefinido**: Tiempo máximo definido para considerar la producción potencial.
#
# **TiempoTransp(CAi)**: Tiempo de transporte desde el centro de acopio **CAi** a su destino.
#
# **Tiempo(CAi)**: Tiempo total en horas para que el pedido llegue desde el centro de acopio **CAi** a su destino, sumando el tiempo de alistamiento y el tiempo de transporte.
#
# **cTiempo**: Costo adicional por cada unidad de tiempo contemplado en la variable **Tiempo(CAi)**.
#
# **Demanda**: Cantidad de producto solicitada por el cliente.
#
# **Stock(CAi)**: Stock del producto en el centro de acopio **CAi**.
#
# **Ppotencial(CAi)**: Cantidad de producto que potencialmente puede estar disponible en poco tiempo (potencial del día).

# %% [markdown]
# *Código desarrollado para la resolución del problema*

# %% [markdown]
# # IMPORTACIONES

# %%
from pyomo.environ import *
import pyomo.environ as pyo
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tabulate import tabulate
from prettytable import PrettyTable
import openpyxl
import time

# %% [markdown]
# **demanda**: Cantidad de producto de acuerdo con la categoría del pedido a satisfacer.
#
# **costo_transporte**: Costo por unidad de tiempo de espera para satisfacer la demanda.
#
# **id**: Identificadores de Centro de Acopio (CAi).
#
# **kg**: Stock del Producto en el Centro de Acopio (Stock(CAi)).
#
# **produccion_potencial**: (Ppotencial(CAi)).
#
# **costos_transporte**: (cTransp(CAi)).
#
# **precio**: Precio del Producto por Kilo (Precio(CAi)).
#
# **tiempos_transporte**:Tiempos de Transporte (TiempoTransp(CAi)).
#
# **tiempo_alistamiento**:Tiempos de Alistamiento (TiempoAlistam(CAi)).

# %%
centros_acopio_df = pd.read_excel('data/centros_acopio.xlsx')
tiempos_transporte_df = pd.read_excel('data/tiempos_transporte.xlsx')
costos_transporte_df = pd.read_excel('data/costo_transporte.xlsx')

# %% [markdown]
# # REPRESENTACIÓN DE DATOS DE ENTRADA

# %%
centros_acopio = centros_acopio_df.copy()
headers = ["Id_CA", "Stock", "Ppotencial", "Precio", "Ctransp", "TiempoTransp", "TiempoAlistam"]
table = [[row["Id_CA"], row["Stock"], row["Ppotencial"], row["Precio"], row["Ctransp"], row["TiempoTransp"], row["TiempoAlistam"]] for _, row in centros_acopio.iterrows()]

print("Centros de Acopio:")
print(tabulate(table, headers=headers, tablefmt='grid'))
print()

costos_transporte_df.columns = [''] + list(costos_transporte_df.columns[1:])
tiempos_transporte_df.columns = [''] + list(tiempos_transporte_df.columns[1:])

print("Tabla 'Costos de Transporte':")
print(tabulate(costos_transporte_df, tablefmt='grid', showindex=False, headers='keys'))
print()

table = PrettyTable()
table.field_names = costos_transporte_df.columns.tolist()
for row in costos_transporte_df.values:
    table.add_row(list(row))

print("Tabla 'Tiempos de Transporte':")
print(tabulate(tiempos_transporte_df, tablefmt='grid', showindex=False, headers='keys'))
print()

table = PrettyTable()
table.field_names = tiempos_transporte_df.columns.tolist()
for row in tiempos_transporte_df.values:
    table.add_row(list(row))

print()
# Out:
# Centros de Acopio:
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | Id_CA   |   Stock |   Ppotencial |   Precio |   Ctransp |   TiempoTransp |   TiempoAlistam |
# +=========+=========+==============+==========+===========+================+=================+
# | CA1     |      10 |        0.5   |     5000 |     21841 |             37 |              10 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA2     |      12 |        0.625 |    10000 |     21180 |             42 |               9 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA3     |       4 |       14     |    15000 |     24132 |             32 |              47 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA4     |       8 |       13     |     2000 |     14215 |             34 |              41 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA5     |      18 |       15     |    30000 |     21654 |             22 |              42 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA6     |       6 |       14     |    50000 |     20303 |             41 |              16 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA7     |      12 |       13     |    15000 |     24553 |             32 |               5 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA8     |       2 |       12.5   |     3000 |     21658 |             16 |              37 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA9     |      30 |       15     |    30000 |     14528 |             27 |              26 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
# | CA10    |      15 |       18     |    19000 |     23424 |             39 |              19 |
# +---------+---------+--------------+----------+-----------+----------------+-----------------+
#
# Tabla 'Costos de Transporte':
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# |      |   CA1 |   CA2 |   CA3 |   CA4 |   CA5 |   CA6 |   CA7 |   CA8 |   CA9 |   CA10 |
# +======+=======+=======+=======+=======+=======+=======+=======+=======+=======+========+
# | CA1  |     0 | 17071 | 29902 | 28862 | 22693 | 26892 | 22793 | 20966 | 21399 |  12712 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA2  | 17071 |     0 | 20339 | 12897 | 28898 | 15196 | 16108 | 14577 | 21908 |  17243 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA3  | 29902 | 20339 |     0 | 23705 | 24941 | 20198 | 26903 | 23788 | 22812 |  24456 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA4  | 28862 | 12897 | 23705 |     0 | 22424 | 20542 | 19060 | 12041 | 19133 |  19640 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA5  | 22693 | 28898 | 24941 | 22424 |     0 | 16321 | 22995 | 14321 | 15803 |  13582 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA6  | 26892 | 15196 | 20198 | 20542 | 16321 |     0 | 13500 | 17573 | 21569 |  25485 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA7  | 22793 | 16108 | 26903 | 19060 | 22995 | 13500 |     0 | 21993 | 16491 |  22089 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA8  | 20966 | 14577 | 23788 | 12041 | 14321 | 17573 | 21993 |     0 | 29942 |  26153 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA9  | 21399 | 21908 | 22812 | 19133 | 15803 | 21569 | 16491 | 29942 |     0 |  17745 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA10 | 12712 | 17243 | 24456 | 19640 | 13582 | 25485 | 22089 | 26153 | 17745 |      0 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
#
# Tabla 'Tiempos de Transporte':
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# |      |   CA1 |   CA2 |   CA3 |   CA4 |   CA5 |   CA6 |   CA7 |   CA8 |   CA9 |   CA10 |
# +======+=======+=======+=======+=======+=======+=======+=======+=======+=======+========+
# | CA1  |     0 |    35 |    19 |    44 |    21 |    43 |    34 |    19 |    12 |     22 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA2  |    35 |     0 |    44 |    17 |    43 |    45 |    22 |    46 |    29 |     15 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA3  |    19 |    44 |     0 |    35 |    23 |    15 |    44 |    30 |    32 |     26 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA4  |    44 |    17 |    35 |     0 |    46 |    28 |    40 |    41 |    12 |     20 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA5  |    21 |    43 |    23 |    46 |     0 |    13 |    28 |    12 |    28 |     35 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA6  |    43 |    45 |    15 |    28 |    13 |     0 |    24 |    46 |    17 |     23 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA7  |    34 |    22 |    44 |    40 |    28 |    24 |     0 |    37 |    19 |     43 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA8  |    19 |    46 |    30 |    41 |    12 |    46 |    37 |     0 |    46 |     47 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA9  |    12 |    29 |    32 |    12 |    28 |    17 |    19 |    46 |     0 |     23 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+
# | CA10 |    22 |    15 |    26 |    20 |    35 |    23 |    43 |    47 |    23 |      0 |
# +------+-------+-------+-------+-------+-------+-------+-------+-------+-------+--------+

# %% [markdown]
# # Creación de tablas de acuerdo al centro de acopio principal asignado

# %%
def obtener_costos_y_tiempos(id_centro_acopio, centro_principal, costos_transporte_df, tiempos_transporte_df):
    """
    Obtiene el costo y tiempo de transporte desde el centro principal al centro especificado.
    
    Parameters:
        id_centro_acopio (str): Identificador del centro de acopio.
        centro_principal (str): Centro de acopio principal.
        costos_transporte_df (DataFrame): DataFrame con los costos de transporte entre centros.
        tiempos_transporte_df (DataFrame): DataFrame con los tiempos de transporte entre centros.

    Returns:
        (float, float): Costo y tiempo de transporte desde el centro principal.
    """
    if id_centro_acopio == centro_principal:
        return 0, 0  # Si es el centro principal, el costo y tiempo son 0
    
    # Encontrar el índice del centro principal
    index_centro_principal = centros_acopio_df.loc[centros_acopio_df['Id_CA'] == centro_principal].index[0]
    
    # Obtener costos y tiempos de transporte
    costo_transporte = costos_transporte_df.at[index_centro_principal, id_centro_acopio]
    tiempo_transporte = tiempos_transporte_df.at[index_centro_principal, id_centro_acopio]
    
    return costo_transporte, tiempo_transporte

# %%
def agregar_fila_final(lista_filas, id_centro_acopio, cantidadS, cantidadP, precio, costo_transporte, tiempo_transporte, tiempo_alistamiento):
    """
    Agrega una fila a la lista de datos finales con los valores calculados.

    Parameters:
        lista_filas (list): Lista para almacenar las filas del DataFrame final.
        id_centro_acopio (str): Identificador del centro de acopio.
        cantidad (int): Cantidad de producto.
        precio (float): Precio del producto.
        costo_transporte (float): Costo de transporte desde el centro principal.
        tiempo_transporte (float): Tiempo de transporte desde el centro principal.
        tiempo_alistamiento (float): Tiempo de alistamiento del producto.
    """
    lista_filas.append({
        'Id_CA': id_centro_acopio,
        'CantidadS': cantidadS,
        'CantidadP': cantidadP,
        'Precio': precio,
        'Ctransp': costo_transporte,
        'TiempoTransp': tiempo_transporte,
        'TiempoAlistam': tiempo_alistamiento
    })

# %%
def generar_dataframe_centros(centro_principal):
    """
    Genera el DataFrame final que contiene la información de los centros de acopio, 
    sus cantidades de producto, precios, costos y tiempos de transporte.
    
    Parameters:
        centro_principal (str): Identificador del centro de acopio principal.

    Returns:
        DataFrame: DataFrame con los datos de centros de acopio, incluyendo transporte y tiempos.
    """
    filas_finales = []
    
    for _, row in centros_acopio_df.iterrows():
        id_centro_acopio = row['Id_CA']
        precio = row['Precio']
        cantidad_stock = row['Stock'] 
        cantidad_potencial = row['Ppotencial']
        tiempo_alistamiento = row['TiempoAlistam']
        
        # Obtener costos y tiempos de transporte
        if(id_centro_acopio == centro_principal): 
            costo_transporte = row['Ctransp'] 
            tiempo_transporte = row['TiempoTransp']
        else :
            costo_transporte, tiempo_transporte = obtener_costos_y_tiempos(
               id_centro_acopio, centro_principal, costos_transporte_df, tiempos_transporte_df)
        
        # Fila para el stock disponible
        
        agregar_fila_final(filas_finales, id_centro_acopio, cantidad_stock, cantidad_potencial,
                           precio, costo_transporte, tiempo_transporte, tiempo_alistamiento)
  
    return pd.DataFrame(filas_finales)

# %%
#centro_principal = 'CA2'
#centros_df_original = generar_dataframe_centros(centro_principal)
#print(centros_df_original)

# %%
def costoTransp_tiempo_CAi2CAP(centro_principal):
    """
    Genera DataFrames dinámicos para costos y tiempos de transporte con base en el centro principal.
    
    Parameters:
        centro_principal (str): Identificador del centro de acopio principal.

    Returns:
        (DataFrame, DataFrame): DataFrames de costos y tiempos de transporte.
    """
    # Encontrar el índice del centro principal
    index_centro_principal = centros_acopio_df.loc[centros_acopio_df['Id_CA'] == centro_principal].index[0]
    
    # Crear DataFrames de costos y tiempos con base en el centro principal
    costos_df = costos_transporte_df.iloc[[index_centro_principal]].reset_index(drop=True)
    tiempos_df = tiempos_transporte_df.iloc[[index_centro_principal]].reset_index(drop=True)
    
    return costos_df, tiempos_df

# %%
# Generar el DataFrame final
#costos_df, tiempos_df = costoTransp_tiempo_CAi2CAP(centro_principal)

#print("DataFrame de Costos de Transporte:")
#print(costos_df)

#print("DataFrame de Tiempos de Transporte:")
#print(tiempos_df)

# %%
def idx_primera_asignacion(CAP, centros_df_CAP):
     idx_CAP = centros_df_CAP.loc[centros_df_CAP['Id_CA'] == CAP].index[0]
     return idx_CAP

# %%
#centros_df_CAP = centros_df_original.copy()
#idx_CAP, costo_CAP = primera_asignacion(centro_principal, centros_df_CAP)
#print(centros_df_CAP)
#print(idx_CAP, costo_CAP)

# %%
def objective_rule(model):
        total_cost = sum(
             model.S[i] * model.Precio[i] + (model.CTransp[i] + model.TiempoTransp[i] * model.costo_tiempo)*model.bs[i] + 
             model.P[i] * model.Precio[i] + (model.TiempoAlistam[i] * model.costo_tiempo)*model.bp[i]
            for i in model.I )
        return total_cost

# %%
def create_model(demanda_cliente, centros_df, idx_CAP):
    num_centros = len(centros_df)
    bigM = centros_df['CantidadS'].sum() + centros_df['CantidadP'].sum() + 1000
    model = pyo.ConcreteModel()
    model.I = pyo.RangeSet(0, num_centros - 1)
    model.demanda = pyo.Param(initialize=demanda_cliente)
    model.costo_tiempo = pyo.Param(initialize=100, mutable=True, within=pyo.NonNegativeReals)
    model.bigM = pyo.Param(initialize=100, within=pyo.NonNegativeReals)
    model.CantidadS = pyo.Param(model.I, initialize=centros_df['CantidadS'].to_dict())
    model.CantidadP = pyo.Param(model.I, initialize=centros_df['CantidadP'].to_dict())
    model.Precio = pyo.Param(model.I, initialize=centros_df['Precio'].to_dict())
    model.CTransp = pyo.Param(model.I, initialize=centros_df['Ctransp'].to_dict())
    model.TiempoTransp = pyo.Param(model.I, initialize=centros_df['TiempoTransp'].to_dict())
    model.TiempoAlistam = pyo.Param(model.I, initialize=centros_df['TiempoAlistam'].to_dict())
    model.CentroPrincipal = pyo.Param(initialize=idx_CAP)
    
    # Variables de decisión
    model.S = pyo.Var(model.I, within=pyo.NonNegativeReals)
    model.P = pyo.Var(model.I, within=pyo.NonNegativeReals)
    model.bp = pyo.Var(model.I, within=pyo.Binary)
    model.bs = pyo.Var(model.I, within=pyo.Binary)
    
    # Restricción de Satisfacción de Demanda
    model.DemandaSatisfecha = pyo.Constraint(expr=sum(model.S[i]+model.P[i] for i in model.I) >= model.demanda)
    model.LimiteCantidadS = pyo.Constraint(model.I, rule=lambda model, i: model.S[i] <= model.CantidadS[i])
    model.LimiteCantidadP = pyo.Constraint(model.I, rule=lambda model, i: model.P[i] <= model.CantidadP[i])
   
    #Toma la cantidad en stock del centro de acopio principal con prioridad
    def first_asignation(model):
        return model.S[model.CentroPrincipal] >= model.CantidadS[model.CentroPrincipal]
    model.CAP = pyo.Constraint(expr=first_asignation)

    #El modelo tomará producción potencial de cualquier centro de acopio solo si ya ha tomado el stock
    def pot_IF_stock_ok(model, i):
        return model.S[i] * bigM >= model.P[i]
    model.pot_IF_stock = Constraint(model.I, rule=pot_IF_stock_ok)
    
    #El tiempo de alistamiento solo se sumará en la función objetivo si se ha tomado la caraga potencial
    def TiempoAlistam_IF_pot_ok(model, i):
        return bigM * model.bp[i] >= model.P[i]
    model.TiempoAlistam_IF_pot = Constraint(model.I, rule=TiempoAlistam_IF_pot_ok)

    #El costo de transporte y tiempo de transporte solo se sumará si se ha tomado el stock
    def TiempoCostoTransp_IF_stock_ok(model, i):
        return bigM * model.bs[i] >= model.S[i]
    model.TiempoCostoTransp_IF_stock = Constraint(model.I, rule=TiempoCostoTransp_IF_stock_ok)
    
    model.CostoTotal = pyo.Objective(rule=objective_rule, sense=pyo.minimize)
    
    return model

# %%
#model = create_model(demanda_cliente, centros_df_CAP)
#solver = pyo.SolverFactory('glpk')
#results = solver.solve(model, tee=True)

# %%
def print_asignation(model, Ids, centros_df_CAP, verbose = 0):
    cant_total = 0
    CA_Ids = centros_acopio_df['Id_CA']
    
    print('\n **** Solución para el CAP: ', Ids)
    for i in model.I:
        cantStock = pyo.value(model.S[i])
        cantPot   = pyo.value(model.P[i])
        #bs = pyo.value(model.bs[i])
        #bp = pyo.value(model.bp[i])
        cant_total += cantStock + cantPot
        print('-> %s: Stock: %f - Potencial: %f' % (CA_Ids[i], cantStock, cantPot))
        #print('  bs: %d - bp: %d' % (bs, bp))

    print('cantidad total asingada = %f ' % cant_total)
    print('Costo total de la asignación: %f' % pyo.value(model.CostoTotal))

    if verbose:
       print('aqui')
       centros_df_CAP['cantStock_asignada'] = [pyo.value(model.S[i]) for i in range(len(centros_df_CAP))] 
       centros_df_CAP['cantPot_asignada'] = [pyo.value(model.P[i]) for i in range(len(centros_df_CAP))]
       centros_df_CAP['BS'] = [pyo.value(model.bs[i]) for i in range(len(centros_df_CAP))]
       centros_df_CAP['BP'] = [pyo.value(model.bp[i]) for i in range(len(centros_df_CAP))]
       centros_df_CAP['costo_stock'] = centros_df_CAP['cantStock_asignada'] * centros_df_CAP['Precio'] + \
                                            (centros_df_CAP['Ctransp'] + centros_df_CAP['TiempoTransp']*100) * centros_df_CAP['BS']
       centros_df_CAP['costo_Potencial'] = centros_df_CAP['cantPot_asignada'] * centros_df_CAP['Precio'] + \
                                            (centros_df_CAP['TiempoAlistam']*100) * centros_df_CAP['BP']
       centros_df_CAP.to_excel('asignacion.xlsx')

# %%
demanda_cliente = 60
CA_Ids = centros_acopio_df['Id_CA']
CAP_sols = []

#CA_Ids = ['CA3']

for Ids in CA_Ids:
    print('\nEjecutando el modelo para el centro de acopio %s como principal ...' % Ids)
    centros_df_CAP = generar_dataframe_centros(Ids)
    costos_df, tiempos_df = costoTransp_tiempo_CAi2CAP(Ids)
    
    idx_CAP = idx_primera_asignacion(Ids, centros_df_CAP)
    model = create_model(demanda_cliente, centros_df_CAP, idx_CAP)
    solver = pyo.SolverFactory('glpk')
    results = solver.solve(model, tee=False)
    
    if results.solver.termination_condition != pyo.TerminationCondition.optimal:
       print("Centro de acopio: ", Ids)
       print(f"El modelo no se resolvió de manera óptima. Estado: {results.solver.termination_condition}")
       print("Posibles razones: restricciones demasiado estrictas, falta de stock o demanda demasiado alta.")
    else:
       CAP_sols.append((Ids, pyo.value(model.CostoTotal))) 
       print_asignation(model, Ids, centros_df_CAP)
  
mejor_sol =  min(CAP_sols, key = lambda t: t[1])
print('\n\nLa mejor solución encontrada fue: %f, CAP: %s ' %(mejor_sol[1], mejor_sol[0]))
# Out:
# Ejecutando el modelo para el centro de acopio CA1 como principal ...
#
#  **** Solución para el CAP:  CA1
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 12.000000 - Potencial: 0.625000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 0.000000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 1.375000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 417227.000000
#
# Ejecutando el modelo para el centro de acopio CA2 como principal ...
#
#  **** Solución para el CAP:  CA2
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 12.000000 - Potencial: 0.625000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 1.375000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 392608.000000
#
# Ejecutando el modelo para el centro de acopio CA3 como principal ...
#
#  **** Solución para el CAP:  CA3
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 10.000000 - Potencial: 0.000000
# -> CA3: Stock: 4.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 0.000000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 444666.000000
#
# Ejecutando el modelo para el centro de acopio CA4 como principal ...
#
#  **** Solución para el CAP:  CA4
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 12.000000 - Potencial: 0.625000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 1.375000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 399250.000000
#
# Ejecutando el modelo para el centro de acopio CA5 como principal ...
#
#  **** Solución para el CAP:  CA5
# -> CA1: Stock: 6.500000 - Potencial: 0.000000
# -> CA2: Stock: 0.000000 - Potencial: 0.000000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 18.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 0.000000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 756992.000000
#
# Ejecutando el modelo para el centro de acopio CA6 como principal ...
#
#  **** Solución para el CAP:  CA6
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 8.000000 - Potencial: 0.000000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 6.000000 - Potencial: 0.000000
# -> CA7: Stock: 0.000000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 647606.000000
#
# Ejecutando el modelo para el centro de acopio CA7 como principal ...
#
#  **** Solución para el CAP:  CA7
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 0.000000 - Potencial: 0.000000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 12.000000 - Potencial: 2.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 459999.000000
#
# Ejecutando el modelo para el centro de acopio CA8 como principal ...
#
#  **** Solución para el CAP:  CA8
# -> CA1: Stock: 10.000000 - Potencial: 0.500000
# -> CA2: Stock: 12.000000 - Potencial: 0.625000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 1.375000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 401710.000000
#
# Ejecutando el modelo para el centro de acopio CA9 como principal ...
#
#  **** Solución para el CAP:  CA9
# -> CA1: Stock: 0.000000 - Potencial: 0.000000
# -> CA2: Stock: 0.000000 - Potencial: 0.000000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 0.000000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 7.000000
# -> CA9: Stock: 30.000000 - Potencial: 0.000000
# -> CA10: Stock: 0.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 1048903.000000
#
# Ejecutando el modelo para el centro de acopio CA10 como principal ...
#
#  **** Solución para el CAP:  CA10
# -> CA1: Stock: 9.500000 - Potencial: 0.000000
# -> CA2: Stock: 0.000000 - Potencial: 0.000000
# -> CA3: Stock: 0.000000 - Potencial: 0.000000
# -> CA4: Stock: 8.000000 - Potencial: 13.000000
# -> CA5: Stock: 0.000000 - Potencial: 0.000000
# -> CA6: Stock: 0.000000 - Potencial: 0.000000
# -> CA7: Stock: 0.000000 - Potencial: 0.000000
# -> CA8: Stock: 2.000000 - Potencial: 12.500000
# -> CA9: Stock: 0.000000 - Potencial: 0.000000
# -> CA10: Stock: 15.000000 - Potencial: 0.000000
# cantidad total asingada = 60.000000
# Costo total de la asignación: 520529.000000
#
#
# La mejor solución encontrada fue: 392608.000000, CAP: CA2
